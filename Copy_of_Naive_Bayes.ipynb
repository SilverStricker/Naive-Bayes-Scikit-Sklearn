# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data = pd.read_csv('/content/gdrive/MyDrive/play.csv')
data = data.drop(columns=['day'])
data.head()
# Out:
#     outlook  temp humidity    wind play
# 0     Sunny   Hot     High    Weak   No
# 1     Sunny   Hot     High  Strong   No
# 2  Overcast   Hot     High    Weak  Yes
# 3      Rain  Mild     High    Weak  Yes
# 4      Rain  Cool   Normal    Weak  Yes

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.outlook = le.fit_transform(data.outlook)
data.temp = le.fit_transform(data.temp)
data.humidity =le.fit_transform(data.humidity)
data.wind =le.fit_transform(data.wind)
data.play = le.fit_transform(data.play)
data
# Out:
#     outlook  temp  humidity  wind  play
# 0         2     1         0     1     0
# 1         2     1         0     0     0
# 2         0     1         0     1     1
# 3         1     2         0     1     1
# 4         1     0         1     1     1
# 5         1     0         1     0     0
# 6         0     0         1     0     1
# 7         2     2         0     1     0
# 8         2     0         1     1     1
# 9         1     2         1     1     1
# 10        2     2         1     0     1
# 11        0     2         0     0     1
# 12        0     1         1     1     1
# 13        1     2         0     0     0

# %%
X = data.drop(['play'], axis=1)

y = data['play']
X
# Out:
#     outlook  temp  humidity  wind
# 0         2     1         0     1
# 1         2     1         0     0
# 2         0     1         0     1
# 3         1     2         0     1
# 4         1     0         1     1
# 5         1     0         1     0
# 6         0     0         1     0
# 7         2     2         0     1
# 8         2     0         1     1
# 9         1     2         1     1
# 10        2     2         1     0
# 11        0     2         0     0
# 12        0     1         1     1
# 13        1     2         0     0

# %%
print(len(X))
# Out:
# 14

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

print(X_train.shape, X_test.shape)
# Out:
# (10, 4) (4, 4)

# %%
from sklearn.naive_bayes import CategoricalNB
clf = CategoricalNB()
clf.fit(X_train, y_train)
print('Predicted Values = ',end =' ')
print(le.inverse_transform(clf.predict(X_test)))
print('\nActual Values = ',end =' ')
print(le.inverse_transform(y_test))
# Out:
# Predicted Values =  ['Yes' 'No' 'No' 'Yes']
#
# Actual Values =  ['Yes' 'Yes' 'No' 'Yes']

# %%
clf.score(X_test,y_test)
# Out:
# 0.75

# %%
data = pd.read_csv('/content/gdrive/MyDrive/music.csv')
data.head()
# Out:
#    Class  _RMSenergy_Mean  _Lowenergy_Mean  _Fluctuation_Mean  _Tempo_Mean  \
# 0  relax            0.052            0.591              9.136      130.043
# 1  relax            0.125            0.439              6.680      142.240
# 2  relax            0.046            0.639             10.578      188.154
# 3  relax            0.135            0.603             10.442       65.991
# 4  relax            0.066            0.591              9.769       88.890
#
#    _MFCC_Mean_1  _MFCC_Mean_2  _MFCC_Mean_3  _MFCC_Mean_4  _MFCC_Mean_5  ...  \
# 0         3.997         0.363         0.887         0.078         0.221  ...
# 1         4.058         0.516         0.785         0.397         0.556  ...
# 2         2.775         0.903         0.502         0.329         0.287  ...
# 3         2.841         1.552         0.612         0.351         0.011  ...
# 4         3.217         0.228         0.814         0.096         0.434  ...
#
#    _Chromagram_Mean_9  _Chromagram_Mean_10  _Chromagram_Mean_11  \
# 0               0.426                1.000                0.008
# 1               0.002                1.000                0.000
# 2               0.184                0.746                0.016
# 3               0.038                1.000                0.161
# 4               0.004                0.404                1.000
#
#    _Chromagram_Mean_12  _HarmonicChangeDetectionFunction_Mean  \
# 0                0.101                                  0.316
# 1                0.984                                  0.285
# 2                1.000                                  0.413
# 3                0.757                                  0.422
# 4                0.001                                  0.345
#
#    _HarmonicChangeDetectionFunction_Std  \
# 0                                 0.261
# 1                                 0.211
# 2                                 0.299
# 3                                 0.265
# 4                                 0.261
#
#    _HarmonicChangeDetectionFunction_Slope  \
# 0                                   0.018
# 1                                  -0.082
# 2                                   0.134
# 3                                   0.042
# 4                                   0.089
#
#    _HarmonicChangeDetectionFunction_PeriodFreq  \
# 0                                        1.035
# 1                                        3.364
# 2                                        1.682
# 3                                        0.354
# 4                                        0.748
#
#    _HarmonicChangeDetectionFunction_PeriodAmp  \
# 0                                       0.593
# 1                                       0.702
# 2                                       0.692
# 3                                       0.743
# 4                                       0.674
#
#    _HarmonicChangeDetectionFunction_PeriodEntropy
# 0                                           0.970
# 1                                           0.967
# 2                                           0.963
# 3                                           0.968
# 4                                           0.957
#
# [5 rows x 51 columns]

# %%
data.Class = le.fit_transform(data.Class)
data
# Out:
#      Class  _RMSenergy_Mean  _Lowenergy_Mean  _Fluctuation_Mean  _Tempo_Mean  \
# 0        2            0.052            0.591              9.136      130.043
# 1        2            0.125            0.439              6.680      142.240
# 2        2            0.046            0.639             10.578      188.154
# 3        2            0.135            0.603             10.442       65.991
# 4        2            0.066            0.591              9.769       88.890
# ..     ...              ...              ...                ...          ...
# 395      0            0.174            0.578              5.265      161.144
# 396      0            0.176            0.498              5.042      179.787
# 397      0            0.187            0.557              4.724      134.032
# 398      0            0.140            0.573              4.470      113.600
# 399      0            0.086            0.475              5.343      151.748
#
#      _MFCC_Mean_1  _MFCC_Mean_2  _MFCC_Mean_3  _MFCC_Mean_4  _MFCC_Mean_5  \
# 0           3.997         0.363         0.887         0.078         0.221
# 1           4.058         0.516         0.785         0.397         0.556
# 2           2.775         0.903         0.502         0.329         0.287
# 3           2.841         1.552         0.612         0.351         0.011
# 4           3.217         0.228         0.814         0.096         0.434
# ..            ...           ...           ...           ...           ...
# 395         2.985         0.065         0.718         0.046         0.265
# 396         2.790        -0.148         0.342        -0.011         0.029
# 397         1.672         0.566         0.880        -0.113         0.244
# 398         1.997        -0.210         0.694         0.089         0.206
# 399         2.240        -0.014         0.834        -0.021         0.345
#
#      ...  _Chromagram_Mean_9  _Chromagram_Mean_10  _Chromagram_Mean_11  \
# 0    ...               0.426                1.000                0.008
# 1    ...               0.002                1.000                0.000
# 2    ...               0.184                0.746                0.016
# 3    ...               0.038                1.000                0.161
# 4    ...               0.004                0.404                1.000
# ..   ...                 ...                  ...                  ...
# 395  ...               0.374                0.838                0.413
# 396  ...               0.020                1.000                0.640
# 397  ...               0.052                0.184                0.287
# 398  ...               0.137                1.000                0.304
# 399  ...               0.099                1.000                0.094
#
#      _Chromagram_Mean_12  _HarmonicChangeDetectionFunction_Mean  \
# 0                  0.101                                  0.316
# 1                  0.984                                  0.285
# 2                  1.000                                  0.413
# 3                  0.757                                  0.422
# 4                  0.001                                  0.345
# ..                   ...                                    ...
# 395                0.125                                  0.323
# 396                0.010                                  0.233
# 397                0.101                                  0.269
# 398                0.140                                  0.277
# 399                0.033                                  0.195
#
#      _HarmonicChangeDetectionFunction_Std  \
# 0                                   0.261
# 1                                   0.211
# 2                                   0.299
# 3                                   0.265
# 4                                   0.261
# ..                                    ...
# 395                                 0.140
# 396                                 0.127
# 397                                 0.157
# 398                                 0.144
# 399                                 0.110
#
#      _HarmonicChangeDetectionFunction_Slope  \
# 0                                     0.018
# 1                                    -0.082
# 2                                     0.134
# 3                                     0.042
# 4                                     0.089
# ..                                      ...
# 395                                   0.120
# 396                                   0.145
# 397                                   0.111
# 398                                   0.061
# 399                                   0.007
#
#      _HarmonicChangeDetectionFunction_PeriodFreq  \
# 0                                          1.035
# 1                                          3.364
# 2                                          1.682
# 3                                          0.354
# 4                                          0.748
# ..                                           ...
# 395                                        2.691
# 396                                        3.364
# 397                                        3.364
# 398                                        3.364
# 399                                        0.641
#
#      _HarmonicChangeDetectionFunction_PeriodAmp  \
# 0                                         0.593
# 1                                         0.702
# 2                                         0.692
# 3                                         0.743
# 4                                         0.674
# ..                                          ...
# 395                                       0.867
# 396                                       0.879
# 397                                       0.819
# 398                                       0.811
# 399                                       0.848
#
#      _HarmonicChangeDetectionFunction_PeriodEntropy
# 0                                             0.970
# 1                                             0.967
# 2                                             0.963
# 3                                             0.968
# 4                                             0.957
# ..                                              ...
# 395                                           0.969
# 396                                           0.967
# 397                                           0.962
# 398                                           0.969
# 399                                           0.965
#
# [400 rows x 51 columns]

# %%
X = data.drop(['Class'], axis=1)
y = data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)
print(X_train.shape, X_test.shape)
# Out:
# (300, 50) (100, 50)

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(X_train, y_train)
print('Predicted Values = ',end =' ')
print(le.inverse_transform(clf.predict(X_test)))
print('\nActual Values = ',end =' ')
print(le.inverse_transform(y_test))
# Out:
# Predicted Values =  ['happy' 'sad' 'relax' 'relax' 'relax' 'relax' 'sad' 'sad' 'sad' 'happy'
#  'sad' 'angry' 'sad' 'relax' 'happy' 'angry' 'angry' 'angry' 'sad' 'angry'
#  'sad' 'relax' 'happy' 'angry' 'relax' 'angry' 'happy' 'sad' 'angry'
#  'happy' 'angry' 'happy' 'relax' 'relax' 'relax' 'happy' 'happy' 'angry'
#  'happy' 'happy' 'angry' 'relax' 'relax' 'relax' 'relax' 'angry' 'happy'
#  'happy' 'relax' 'happy' 'relax' 'happy' 'happy' 'relax' 'angry' 'relax'
#  'sad' 'sad' 'relax' 'happy' 'angry' 'happy' 'happy' 'sad' 'happy' 'relax'
#  'happy' 'sad' 'happy' 'relax' 'relax' 'happy' 'sad' 'relax' 'angry'
#  'angry' 'happy' 'angry' 'happy' 'relax' 'relax' 'sad' 'relax' 'sad' 'sad'
#  'relax' 'relax' 'angry' 'happy' 'relax' 'relax' 'angry' 'happy' 'sad'
#  'happy' 'angry' 'angry' 'happy' 'happy' 'relax']
#
# Actual Values =  ['sad' 'sad' 'relax' 'sad' 'relax' 'relax' 'angry' 'relax' 'sad' 'happy'
#  'relax' 'angry' 'relax' 'relax' 'happy' 'relax' 'sad' 'angry' 'sad'
#  'angry' 'relax' 'relax' 'angry' 'sad' 'relax' 'angry' 'happy' 'sad' 'sad'
#  'happy' 'angry' 'happy' 'sad' 'relax' 'sad' 'happy' 'happy' 'angry'
#  'happy' 'happy' 'angry' 'relax' 'relax' 'relax' 'relax' 'angry' 'happy'
#  'happy' 'relax' 'happy' 'relax' 'angry' 'angry' 'relax' 'angry' 'relax'
#  'sad' 'happy' 'relax' 'happy' 'happy' 'sad' 'sad' 'relax' 'happy' 'relax'
#  'angry' 'sad' 'angry' 'relax' 'angry' 'happy' 'relax' 'relax' 'angry'
#  'sad' 'sad' 'angry' 'happy' 'sad' 'relax' 'relax' 'sad' 'sad' 'sad'
#  'relax' 'sad' 'angry' 'happy' 'relax' 'sad' 'angry' 'happy' 'sad' 'happy'
#  'angry' 'angry' 'angry' 'sad' 'relax']

# %%
clf.score(X_test,y_test)
# Out:
# 0.66
